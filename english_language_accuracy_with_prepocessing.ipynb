# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/A Machine Learning Based Approach to Classify Tense from English Text/Dataset/TenseUniqueDataset.xlsx')

# %%
df.columns
# Out:
# Index(['Labels', 'Sentence'], dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay, roc_auc_score
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.utils import to_categorical

# Load your dataset
#df = pd.read_excel('/content/drive/MyDrive/A Machine Learning Based Approach to Classify Tense from English Text/Dataset/TenseUniqueDataset.xlsx')

# Assuming the dataset has 'Sentence' and 'Tense' columns
sentences = df['Sentence'].values
labels = df['Labels'].values

# Check unique values in labels
unique_labels = np.unique(labels)
print(f"Unique labels in the dataset: {unique_labels}")

# Encode the labels
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Check the transformed labels
transformed_unique_labels = np.unique(labels)
print(f"Transformed unique labels: {transformed_unique_labels}")

# Ensure num_classes matches the number of unique labels
num_classes = len(transformed_unique_labels)
labels = to_categorical(labels, num_classes=num_classes)

# Tokenize the sentences
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentences)
word_index = tokenizer.word_index
sentence_lengths = [len(seq) for seq in sequences]

# Pad the sequences
max_sequence_length = int(np.percentile(sentence_lengths, 95))
data = pad_sequences(sequences, maxlen=max_sequence_length)

embedding_dim = 200
# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.15, random_state=42)

# Build the Bi-LSTM model
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=embedding_dim, input_length=max_sequence_length))
model.add(LSTM(64))
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=37, validation_data=(X_val, y_val))

# Evaluate the model
loss, accuracy = model.evaluate(X_val, y_val)
print(f'Validation Accuracy: {accuracy * 100:.2f}%')

# General and Normalized Confusion Matrix
y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_val, axis=1)

cm = confusion_matrix(y_true, y_pred_classes)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
cm_display.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

cm_normalized = confusion_matrix(y_true, y_pred_classes, normalize='true')
cm_normalized_display = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=label_encoder.classes_)
cm_normalized_display.plot(cmap=plt.cm.Blues)
plt.title('Normalized Confusion Matrix')
plt.show()

# Accuracy and Loss Curves
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# ROC and AUC Curves
fpr = {}
tpr = {}
roc_auc = {}

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_val[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plotting the ROC curve for each class
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# Calculate macro and micro average ROC AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_val.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(num_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= num_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

plt.plot(fpr["micro"], tpr["micro"], label=f'micro-average ROC curve (AUC = {roc_auc["micro"]:.2f})', linestyle=':')
plt.plot(fpr["macro"], tpr["macro"], label=f'macro-average ROC curve (AUC = {roc_auc["macro"]:.2f})', linestyle=':')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Micro and Macro ROC Curves')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# Unique labels in the dataset: [1 2 3]
# Transformed unique labels: [0 1 2]
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - accuracy: 0.7797 - loss: 0.4428 - val_accuracy: 0.9895 - val_loss: 0.0386
# Epoch 2/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9956 - loss: 0.0165 - val_accuracy: 0.9930 - val_loss: 0.0271
# Epoch 3/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.9982 - loss: 0.0068 - val_accuracy: 0.9880 - val_loss: 0.0375
# Epoch 4/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.9996 - loss: 0.0021 - val_accuracy: 0.9870 - val_loss: 0.0439
# Epoch 5/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9990 - loss: 0.0025 - val_accuracy: 0.9885 - val_loss: 0.0533
# Epoch 6/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 1.0000 - loss: 1.3946e-04 - val_accuracy: 0.9895 - val_loss: 0.0535
# Epoch 7/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 1.0000 - loss: 6.9299e-05 - val_accuracy: 0.9890 - val_loss: 0.0585
# Epoch 8/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 1.0000 - loss: 1.6600e-05 - val_accuracy: 0.9885 - val_loss: 0.0608
# Epoch 9/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 16s 54ms/step - accuracy: 1.0000 - loss: 1.9466e-05 - val_accuracy: 0.9890 - val_loss: 0.0602
# Epoch 10/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 16s 38ms/step - accuracy: 1.0000 - loss: 9.4715e-06 - val_accuracy: 0.9885 - val_loss: 0.0636
# Epoch 11/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 1.0000 - loss: 9.1770e-06 - val_accuracy: 0.9890 - val_loss: 0.0636
# Epoch 12/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 1.0000 - loss: 9.1773e-06 - val_accuracy: 0.9895 - val_loss: 0.0638
# Epoch 13/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 1.0000 - loss: 5.3767e-06 - val_accuracy: 0.9890 - val_loss: 0.0651
# Epoch 14/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 1.0000 - loss: 4.1695e-06 - val_accuracy: 0.9890 - val_loss: 0.0672
# Epoch 15/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - accuracy: 1.0000 - loss: 4.7754e-06 - val_accuracy: 0.9890 - val_loss: 0.0676
# Epoch 16/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 1.0000 - loss: 3.0191e-06 - val_accuracy: 0.9890 - val_loss: 0.0681
# Epoch 17/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 1.0000 - loss: 2.4315e-06 - val_accuracy: 0.9895 - val_loss: 0.0698
# Epoch 18/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 1.0000 - loss: 1.7784e-06 - val_accuracy: 0.9895 - val_loss: 0.0698
# Epoch 19/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 1.0000 - loss: 1.3106e-06 - val_accuracy: 0.9895 - val_loss: 0.0729
# Epoch 20/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 42ms/step - accuracy: 1.0000 - loss: 1.1976e-06 - val_accuracy: 0.9895 - val_loss: 0.0717
# Epoch 21/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 1.0000 - loss: 9.0381e-07 - val_accuracy: 0.9895 - val_loss: 0.0751
# Epoch 22/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 1.0000 - loss: 1.1051e-06 - val_accuracy: 0.9895 - val_loss: 0.0747
# Epoch 23/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 1.0000 - loss: 6.0241e-07 - val_accuracy: 0.9895 - val_loss: 0.0757
# Epoch 24/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 1.0000 - loss: 4.3269e-07 - val_accuracy: 0.9895 - val_loss: 0.0759
# Epoch 25/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 1.0000 - loss: 6.2861e-07 - val_accuracy: 0.9895 - val_loss: 0.0772
# Epoch 26/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 1.0000 - loss: 5.3738e-07 - val_accuracy: 0.9900 - val_loss: 0.0771
# Epoch 27/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 1.0000 - loss: 4.4001e-07 - val_accuracy: 0.9895 - val_loss: 0.0793
# Epoch 28/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 1.0000 - loss: 3.3325e-07 - val_accuracy: 0.9895 - val_loss: 0.0793
# Epoch 29/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 1.0000 - loss: 2.5129e-07 - val_accuracy: 0.9895 - val_loss: 0.0811
# Epoch 30/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 39ms/step - accuracy: 1.0000 - loss: 1.4900e-07 - val_accuracy: 0.9890 - val_loss: 0.0819
# Epoch 31/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 1.0000 - loss: 1.4016e-07 - val_accuracy: 0.9895 - val_loss: 0.0837
# Epoch 32/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 22s 44ms/step - accuracy: 1.0000 - loss: 1.0550e-07 - val_accuracy: 0.9890 - val_loss: 0.0833
# Epoch 33/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 1.0000 - loss: 1.1747e-07 - val_accuracy: 0.9895 - val_loss: 0.0850
# Epoch 34/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 1.0000 - loss: 6.1363e-08 - val_accuracy: 0.9895 - val_loss: 0.0871
# Epoch 35/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 1.0000 - loss: 6.3806e-08 - val_accuracy: 0.9895 - val_loss: 0.0849
# Epoch 36/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 1.0000 - loss: 5.8448e-08 - val_accuracy: 0.9895 - val_loss: 0.0872
# Epoch 37/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 41ms/step - accuracy: 1.0000 - loss: 5.1632e-08 - val_accuracy: 0.9890 - val_loss: 0.0884
# Epoch 38/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 1.0000 - loss: 2.9091e-08 - val_accuracy: 0.9895 - val_loss: 0.0902
# Epoch 39/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 1.0000 - loss: 4.2234e-08 - val_accuracy: 0.9895 - val_loss: 0.0888
# Epoch 40/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 1.0000 - loss: 2.3081e-08 - val_accuracy: 0.9895 - val_loss: 0.0908
# Epoch 41/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 1.0000 - loss: 2.0178e-08 - val_accuracy: 0.9895 - val_loss: 0.0918
# Epoch 42/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 1.0000 - loss: 1.8827e-08 - val_accuracy: 0.9895 - val_loss: 0.0927
# Epoch 43/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 1.0000 - loss: 2.2375e-08 - val_accuracy: 0.9895 - val_loss: 0.0931
# Epoch 44/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 1.0000 - loss: 1.7156e-08 - val_accuracy: 0.9895 - val_loss: 0.0955
# Epoch 45/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 24s 54ms/step - accuracy: 1.0000 - loss: 1.5215e-08 - val_accuracy: 0.9905 - val_loss: 0.0924
# Epoch 46/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 1.0000 - loss: 1.7699e-08 - val_accuracy: 0.9905 - val_loss: 0.0933
# Epoch 47/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 1.0000 - loss: 1.2565e-08 - val_accuracy: 0.9900 - val_loss: 0.0975
# Epoch 48/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 1.0000 - loss: 9.4827e-09 - val_accuracy: 0.9900 - val_loss: 0.0963
# Epoch 49/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 1.0000 - loss: 5.4494e-09 - val_accuracy: 0.9900 - val_loss: 0.0984
# Epoch 50/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 1.0000 - loss: 7.4068e-09 - val_accuracy: 0.9900 - val_loss: 0.0990
# Epoch 51/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 1.0000 - loss: 4.7073e-09 - val_accuracy: 0.9900 - val_loss: 0.1008
# Epoch 52/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 1.0000 - loss: 4.4790e-09 - val_accuracy: 0.9900 - val_loss: 0.0998
# Epoch 53/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 1.0000 - loss: 4.2719e-09 - val_accuracy: 0.9900 - val_loss: 0.1021
# Epoch 54/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 1.0000 - loss: 4.1892e-09 - val_accuracy: 0.9905 - val_loss: 0.1017
# Epoch 55/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - accuracy: 1.0000 - loss: 3.5582e-09 - val_accuracy: 0.9905 - val_loss: 0.1019
# Epoch 56/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 1.0000 - loss: 2.2968e-09 - val_accuracy: 0.9900 - val_loss: 0.1038
# Epoch 57/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 1.0000 - loss: 2.2587e-09 - val_accuracy: 0.9900 - val_loss: 0.1034
# Epoch 58/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 1.0000 - loss: 1.5731e-09 - val_accuracy: 0.9900 - val_loss: 0.1063
# Epoch 59/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 1.0000 - loss: 1.5484e-09 - val_accuracy: 0.9900 - val_loss: 0.1059
# Epoch 60/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 23s 48ms/step - accuracy: 1.0000 - loss: 1.4053e-09 - val_accuracy: 0.9905 - val_loss: 0.1052
# Epoch 61/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 18s 40ms/step - accuracy: 1.0000 - loss: 1.0259e-09 - val_accuracy: 0.9905 - val_loss: 0.1063
# Epoch 62/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 43ms/step - accuracy: 1.0000 - loss: 9.8280e-10 - val_accuracy: 0.9905 - val_loss: 0.1061
# Epoch 63/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 1.0000 - loss: 6.9833e-10 - val_accuracy: 0.9900 - val_loss: 0.1082
# Epoch 64/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - accuracy: 1.0000 - loss: 8.5434e-10 - val_accuracy: 0.9905 - val_loss: 0.1081
# Epoch 65/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 1.0000 - loss: 6.8156e-10 - val_accuracy: 0.9905 - val_loss: 0.1091
# Epoch 66/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 1.0000 - loss: 5.3611e-10 - val_accuracy: 0.9905 - val_loss: 0.1122
# Epoch 67/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 1.0000 - loss: 6.1556e-10 - val_accuracy: 0.9900 - val_loss: 0.1131
# Epoch 68/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 1.0000 - loss: 7.9085e-10 - val_accuracy: 0.9900 - val_loss: 0.1120
# Epoch 69/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 1.0000 - loss: 4.8493e-10 - val_accuracy: 0.9915 - val_loss: 0.1068
# Epoch 70/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 1.0000 - loss: 5.6504e-10 - val_accuracy: 0.9910 - val_loss: 0.1098
# Epoch 71/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 1.0000 - loss: 6.1871e-10 - val_accuracy: 0.9905 - val_loss: 0.1133
# Epoch 72/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 1.0000 - loss: 4.1613e-10 - val_accuracy: 0.9905 - val_loss: 0.1120
# Epoch 73/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 35ms/step - accuracy: 1.0000 - loss: 3.4492e-10 - val_accuracy: 0.9900 - val_loss: 0.1158
# Epoch 74/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - accuracy: 1.0000 - loss: 3.7624e-10 - val_accuracy: 0.9910 - val_loss: 0.1127
# Epoch 75/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 1.0000 - loss: 2.2607e-10 - val_accuracy: 0.9895 - val_loss: 0.1118
# Epoch 76/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9909 - loss: 0.0685 - val_accuracy: 0.9905 - val_loss: 0.0388
# Epoch 77/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9905 - val_loss: 0.0437
# Epoch 78/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9998 - loss: 3.4815e-04 - val_accuracy: 0.9900 - val_loss: 0.0460
# Epoch 79/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 1.0000 - loss: 7.8363e-05 - val_accuracy: 0.9905 - val_loss: 0.0499
# Epoch 80/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - accuracy: 1.0000 - loss: 5.1467e-05 - val_accuracy: 0.9905 - val_loss: 0.0517
# Epoch 81/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 1.0000 - loss: 2.5635e-05 - val_accuracy: 0.9900 - val_loss: 0.0534
# Epoch 82/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 1.0000 - loss: 2.9290e-05 - val_accuracy: 0.9900 - val_loss: 0.0551
# Epoch 83/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 1.0000 - loss: 1.4710e-05 - val_accuracy: 0.9905 - val_loss: 0.0564
# Epoch 84/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 1.0000 - loss: 1.3001e-05 - val_accuracy: 0.9905 - val_loss: 0.0573
# Epoch 85/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 1.0000 - loss: 1.3391e-05 - val_accuracy: 0.9905 - val_loss: 0.0584
# Epoch 86/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 1.0000 - loss: 8.3327e-06 - val_accuracy: 0.9900 - val_loss: 0.0594
# Epoch 87/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 1.0000 - loss: 7.9137e-06 - val_accuracy: 0.9900 - val_loss: 0.0603
# Epoch 88/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - accuracy: 1.0000 - loss: 5.2377e-06 - val_accuracy: 0.9900 - val_loss: 0.0612
# Epoch 89/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 1.0000 - loss: 5.4235e-06 - val_accuracy: 0.9900 - val_loss: 0.0620
# Epoch 90/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 1.0000 - loss: 3.5407e-06 - val_accuracy: 0.9905 - val_loss: 0.0628
# Epoch 91/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 1.0000 - loss: 2.4016e-06 - val_accuracy: 0.9905 - val_loss: 0.0636
# Epoch 92/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 42ms/step - accuracy: 1.0000 - loss: 2.5398e-06 - val_accuracy: 0.9905 - val_loss: 0.0645
# Epoch 93/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 38ms/step - accuracy: 1.0000 - loss: 2.1375e-06 - val_accuracy: 0.9905 - val_loss: 0.0653
# Epoch 94/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 1.0000 - loss: 1.6486e-06 - val_accuracy: 0.9905 - val_loss: 0.0660
# Epoch 95/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 1.0000 - loss: 1.8740e-06 - val_accuracy: 0.9905 - val_loss: 0.0667
# Epoch 96/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 19s 44ms/step - accuracy: 1.0000 - loss: 1.3061e-06 - val_accuracy: 0.9905 - val_loss: 0.0675
# Epoch 97/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 1.0000 - loss: 9.7139e-07 - val_accuracy: 0.9905 - val_loss: 0.0683
# Epoch 98/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 21s 42ms/step - accuracy: 1.0000 - loss: 7.7734e-07 - val_accuracy: 0.9905 - val_loss: 0.0692
# Epoch 99/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 1.0000 - loss: 7.6681e-07 - val_accuracy: 0.9905 - val_loss: 0.0698
# Epoch 100/100
# 306/306 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 1.0000 - loss: 7.7039e-07 - val_accuracy: 0.9905 - val_loss: 0.0705
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9883 - loss: 0.0922
# Validation Accuracy: 99.05%
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
