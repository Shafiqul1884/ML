# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
date=pd.read_csv('/content/drive/MyDrive/Dataset/Time and date/orders.csv')

# %%
time=pd.read_csv('/content/drive/MyDrive/Dataset/Time and date/messages.csv')

# %%
date
# Out:
#            date  product_id  city_id  orders
# 0    2019-12-10        5628       25       3
# 1    2018-08-15        3646       14     157
# 2    2018-10-23        1859       25       1
# 3    2019-08-17        7292       25       1
# 4    2019-01-06        4344       25       3
# ..          ...         ...      ...     ...
# 995  2018-10-08         255       13       1
# 996  2018-12-06        5521        7       1
# 997  2019-05-07         487       26      14
# 998  2019-03-03        1503       21       2
# 999  2019-10-15        6371        7      22
#
# [1000 rows x 4 columns]

# %%
time
# Out:
#                     date                                                msg
# 0    2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1    2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2    2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3    2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4    2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                   ...                                                ...
# 995  2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996  2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997  2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998  2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999  2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
# [1000 rows x 2 columns]

# %%
date['date']=pd.to_datetime(date['date'])

# %% [markdown]
# # 1.Extract year

# %%
date['date_year'] = date['date'].dt.year

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year
# 0   2019-12-10        5628       25       3       2019
# 1   2018-08-15        3646       14     157       2018
# 2   2018-10-23        1859       25       1       2018
# 3   2019-08-17        7292       25       1       2019
# 4   2019-01-06        4344       25       3       2019
# ..         ...         ...      ...     ...        ...
# 995 2018-10-08         255       13       1       2018
# 996 2018-12-06        5521        7       1       2018
# 997 2019-05-07         487       26      14       2019
# 998 2019-03-03        1503       21       2       2019
# 999 2019-10-15        6371        7      22       2019
#
# [1000 rows x 5 columns]

# %% [markdown]
# # Extract month

# %%
date['date_month'] = date['date'].dt.month

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month
# 0   2019-12-10        5628       25       3       2019          12
# 1   2018-08-15        3646       14     157       2018           8
# 2   2018-10-23        1859       25       1       2018          10
# 3   2019-08-17        7292       25       1       2019           8
# 4   2019-01-06        4344       25       3       2019           1
# ..         ...         ...      ...     ...        ...         ...
# 995 2018-10-08         255       13       1       2018          10
# 996 2018-12-06        5521        7       1       2018          12
# 997 2019-05-07         487       26      14       2019           5
# 998 2019-03-03        1503       21       2       2019           3
# 999 2019-10-15        6371        7      22       2019          10
#
# [1000 rows x 6 columns]

# %%
date['date_day'] = date['date'].dt.day

# %%
date['date_dow']=date['date'].dt.dayofweek

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month  date_day  \
# 0   2019-12-10        5628       25       3       2019          12        10
# 1   2018-08-15        3646       14     157       2018           8        15
# 2   2018-10-23        1859       25       1       2018          10        23
# 3   2019-08-17        7292       25       1       2019           8        17
# 4   2019-01-06        4344       25       3       2019           1         6
# ..         ...         ...      ...     ...        ...         ...       ...
# 995 2018-10-08         255       13       1       2018          10         8
# 996 2018-12-06        5521        7       1       2018          12         6
# 997 2019-05-07         487       26      14       2019           5         7
# 998 2019-03-03        1503       21       2       2019           3         3
# 999 2019-10-15        6371        7      22       2019          10        15
#
#      date_dow
# 0           1
# 1           2
# 2           1
# 3           5
# 4           6
# ..        ...
# 995         0
# 996         3
# 997         1
# 998         6
# 999         1
#
# [1000 rows x 8 columns]

# %%
date['date_dow_name']=date['date'].dt.day_name()

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month  date_day  \
# 0   2019-12-10        5628       25       3       2019          12        10
# 1   2018-08-15        3646       14     157       2018           8        15
# 2   2018-10-23        1859       25       1       2018          10        23
# 3   2019-08-17        7292       25       1       2019           8        17
# 4   2019-01-06        4344       25       3       2019           1         6
# ..         ...         ...      ...     ...        ...         ...       ...
# 995 2018-10-08         255       13       1       2018          10         8
# 996 2018-12-06        5521        7       1       2018          12         6
# 997 2019-05-07         487       26      14       2019           5         7
# 998 2019-03-03        1503       21       2       2019           3         3
# 999 2019-10-15        6371        7      22       2019          10        15
#
#      date_dow date_dow_name
# 0           1       Tuesday
# 1           2     Wednesday
# 2           1       Tuesday
# 3           5      Saturday
# 4           6        Sunday
# ..        ...           ...
# 995         0        Monday
# 996         3      Thursday
# 997         1       Tuesday
# 998         6        Sunday
# 999         1       Tuesday
#
# [1000 rows x 9 columns]

# %%
date['date_month_name']= date['date'].dt.month_name()

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month  date_day  \
# 0   2019-12-10        5628       25       3       2019          12        10
# 1   2018-08-15        3646       14     157       2018           8        15
# 2   2018-10-23        1859       25       1       2018          10        23
# 3   2019-08-17        7292       25       1       2019           8        17
# 4   2019-01-06        4344       25       3       2019           1         6
# ..         ...         ...      ...     ...        ...         ...       ...
# 995 2018-10-08         255       13       1       2018          10         8
# 996 2018-12-06        5521        7       1       2018          12         6
# 997 2019-05-07         487       26      14       2019           5         7
# 998 2019-03-03        1503       21       2       2019           3         3
# 999 2019-10-15        6371        7      22       2019          10        15
#
#      date_dow date_dow_name date_month_name
# 0           1       Tuesday        December
# 1           2     Wednesday          August
# 2           1       Tuesday         October
# 3           5      Saturday          August
# 4           6        Sunday         January
# ..        ...           ...             ...
# 995         0        Monday         October
# 996         3      Thursday        December
# 997         1       Tuesday             May
# 998         6        Sunday           March
# 999         1       Tuesday         October
#
# [1000 rows x 10 columns]

# %%
date['date_is_weekend']=np.where(date['date_dow_name'].isin(['Sunday','Saturday']),1,0)
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month  date_day  date_dow date_dow_name  \
# 0 2019-12-10       2019          12        10         1       Tuesday
# 1 2018-08-15       2018           8        15         2     Wednesday
# 2 2018-10-23       2018          10        23         1       Tuesday
# 3 2019-08-17       2019           8        17         5      Saturday
# 4 2019-01-06       2019           1         6         6        Sunday
#
#   date_month_name  date_is_weekend
# 0        December                0
# 1          August                0
# 2         October                0
# 3          August                1
# 4         January                1

# %%
date['date_week'] = date['date'].dt.isocalendar().week

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month  date_day  \
# 0   2019-12-10        5628       25       3       2019          12        10
# 1   2018-08-15        3646       14     157       2018           8        15
# 2   2018-10-23        1859       25       1       2018          10        23
# 3   2019-08-17        7292       25       1       2019           8        17
# 4   2019-01-06        4344       25       3       2019           1         6
# ..         ...         ...      ...     ...        ...         ...       ...
# 995 2018-10-08         255       13       1       2018          10         8
# 996 2018-12-06        5521        7       1       2018          12         6
# 997 2019-05-07         487       26      14       2019           5         7
# 998 2019-03-03        1503       21       2       2019           3         3
# 999 2019-10-15        6371        7      22       2019          10        15
#
#      date_dow date_dow_name date_month_name  date_is_weekend  date_week
# 0           1       Tuesday        December                0         50
# 1           2     Wednesday          August                0         33
# 2           1       Tuesday         October                0         43
# 3           5      Saturday          August                1         33
# 4           6        Sunday         January                1          1
# ..        ...           ...             ...              ...        ...
# 995         0        Monday         October                0         41
# 996         3      Thursday        December                0         49
# 997         1       Tuesday             May                0         19
# 998         6        Sunday           March                1          9
# 999         1       Tuesday         October                0         42
#
# [1000 rows x 12 columns]

# %%
date['quarter']=date['date'].dt.quarter

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month  date_day  \
# 0   2019-12-10        5628       25       3       2019          12        10
# 1   2018-08-15        3646       14     157       2018           8        15
# 2   2018-10-23        1859       25       1       2018          10        23
# 3   2019-08-17        7292       25       1       2019           8        17
# 4   2019-01-06        4344       25       3       2019           1         6
# ..         ...         ...      ...     ...        ...         ...       ...
# 995 2018-10-08         255       13       1       2018          10         8
# 996 2018-12-06        5521        7       1       2018          12         6
# 997 2019-05-07         487       26      14       2019           5         7
# 998 2019-03-03        1503       21       2       2019           3         3
# 999 2019-10-15        6371        7      22       2019          10        15
#
#      date_dow date_dow_name date_month_name  date_is_weekend  date_week  \
# 0           1       Tuesday        December                0         50
# 1           2     Wednesday          August                0         33
# 2           1       Tuesday         October                0         43
# 3           5      Saturday          August                1         33
# 4           6        Sunday         January                1          1
# ..        ...           ...             ...              ...        ...
# 995         0        Monday         October                0         41
# 996         3      Thursday        December                0         49
# 997         1       Tuesday             May                0         19
# 998         6        Sunday           March                1          9
# 999         1       Tuesday         October                0         42
#
#      quarter
# 0          4
# 1          3
# 2          4
# 3          3
# 4          1
# ..       ...
# 995        4
# 996        4
# 997        2
# 998        1
# 999        4
#
# [1000 rows x 13 columns]

# %%
date['semester']=np.where(date['quarter'].isin([1,2]),1,2)

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month  date_day  \
# 0   2019-12-10        5628       25       3       2019          12        10
# 1   2018-08-15        3646       14     157       2018           8        15
# 2   2018-10-23        1859       25       1       2018          10        23
# 3   2019-08-17        7292       25       1       2019           8        17
# 4   2019-01-06        4344       25       3       2019           1         6
# ..         ...         ...      ...     ...        ...         ...       ...
# 995 2018-10-08         255       13       1       2018          10         8
# 996 2018-12-06        5521        7       1       2018          12         6
# 997 2019-05-07         487       26      14       2019           5         7
# 998 2019-03-03        1503       21       2       2019           3         3
# 999 2019-10-15        6371        7      22       2019          10        15
#
#      date_dow date_dow_name date_month_name  date_is_weekend  date_week  \
# 0           1       Tuesday        December                0         50
# 1           2     Wednesday          August                0         33
# 2           1       Tuesday         October                0         43
# 3           5      Saturday          August                1         33
# 4           6        Sunday         January                1          1
# ..        ...           ...             ...              ...        ...
# 995         0        Monday         October                0         41
# 996         3      Thursday        December                0         49
# 997         1       Tuesday             May                0         19
# 998         6        Sunday           March                1          9
# 999         1       Tuesday         October                0         42
#
#      quarter  semester
# 0          4         2
# 1          3         2
# 2          4         2
# 3          3         2
# 4          1         1
# ..       ...       ...
# 995        4         2
# 996        4         2
# 997        2         1
# 998        1         1
# 999        4         2
#
# [1000 rows x 14 columns]

# %% [markdown]
# Extract time elapsed between dates

# %%
import datetime
today=datetime.datetime.today()
today
# Out:
# datetime.datetime(2024, 11, 18, 3, 47, 44, 622746)

# %%
today-date['date']
# Out:
# 0     1805 days 03:47:44.622746
# 1     2287 days 03:47:44.622746
# 2     2218 days 03:47:44.622746
# 3     1920 days 03:47:44.622746
# 4     2143 days 03:47:44.622746
#                  ...
# 995   2233 days 03:47:44.622746
# 996   2174 days 03:47:44.622746
# 997   2022 days 03:47:44.622746
# 998   2087 days 03:47:44.622746
# 999   1861 days 03:47:44.622746
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today-date['date']).dt.days
# Out:
# 0      1805
# 1      2287
# 2      2218
# 3      1920
# 4      2143
#        ...
# 995    2233
# 996    2174
# 997    2022
# 998    2087
# 999    1861
# Name: date, Length: 1000, dtype: int64

# %%
(today-date['date']).dt.days/30
# Out:
# 0      60.166667
# 1      76.233333
# 2      73.933333
# 3      64.000000
# 4      71.433333
#          ...
# 995    74.433333
# 996    72.466667
# 997    67.400000
# 998    69.566667
# 999    62.033333
# Name: date, Length: 1000, dtype: float64

# %%
time
# Out:
#                     date                                                msg
# 0    2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1    2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2    2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3    2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4    2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                   ...                                                ...
# 995  2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996  2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997  2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998  2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999  2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
# [1000 rows x 2 columns]

# %%
time['date']=pd.to_datetime(time['date'])

# %%
time['hour']=time['date'].dt.hour
time['min']=time['date'].dt.minute
time['sec']=time['date'].dt.second
time
# Out:
#                    date                                                msg  \
# 0   2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1   2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2   2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3   2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4   2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                  ...                                                ...
# 995 2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996 2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997 2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998 2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999 2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
#      hour  min  sec
# 0       0   50    0
# 1      23   40    0
# 2       0   21    0
# 3       0   31    0
# 4      23   11    0
# ..    ...  ...  ...
# 995     0   50    0
# 996    23   14    0
# 997    23   37    0
# 998    23   34    0
# 999    23   25    0
#
# [1000 rows x 5 columns]

# %%
time['time']=time['date'].dt.time

# %%
time
# Out:
#                    date                                                msg  \
# 0   2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1   2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2   2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3   2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4   2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                  ...                                                ...
# 995 2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996 2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997 2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998 2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999 2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
#      hour  min  sec      time
# 0       0   50    0  00:50:00
# 1      23   40    0  23:40:00
# 2       0   21    0  00:21:00
# 3       0   31    0  00:31:00
# 4      23   11    0  23:11:00
# ..    ...  ...  ...       ...
# 995     0   50    0  00:50:00
# 996    23   14    0  23:14:00
# 997    23   37    0  23:37:00
# 998    23   34    0  23:34:00
# 999    23   25    0  23:25:00
#
# [1000 rows x 6 columns]

# %%
today-time['date']
# Out:
# 0     3991 days 02:57:44.622746
# 1     3855 days 04:07:44.622746
# 2     4341 days 03:26:44.622746
# 3     3643 days 03:16:44.622746
# 4     4040 days 04:36:44.622746
#                  ...
# 995   4630 days 02:57:44.622746
# 996   3951 days 04:33:44.622746
# 997   4416 days 04:10:44.622746
# 998   4532 days 04:13:44.622746
# 999   3804 days 04:22:44.622746
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today-time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.448331e+08
# 1      3.330869e+08
# 2      3.750748e+08
# 3      3.147670e+08
# 4      3.490726e+08
#            ...
# 995    4.000427e+08
# 996    3.413828e+08
# 997    3.815574e+08
# 998    3.915800e+08
# 999    3.286814e+08
# Name: date, Length: 1000, dtype: float64

# %%
(today-time['date'])/np.timedelta64(1,'m')
# Out:
# 0      5.747218e+06
# 1      5.551448e+06
# 2      6.251247e+06
# 3      5.246117e+06
# 4      5.817877e+06
#            ...
# 995    6.667378e+06
# 996    5.689714e+06
# 997    6.359291e+06
# 998    6.526334e+06
# 999    5.478023e+06
# Name: date, Length: 1000, dtype: float64

# %%
(today-time['date'])/np.timedelta64(1,'h')
# Out:
# 0       95786.962395
# 1       92524.129062
# 2      104187.445729
# 3       87435.279062
# 4       96964.612395
#            ...
# 995    111122.962395
# 996     94828.562395
# 997    105988.179062
# 998    108772.229062
# 999     91300.379062
# Name: date, Length: 1000, dtype: float64
