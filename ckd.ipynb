# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-7-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Chronic_Kidney_Dsease_data.csv')
df
# Out:
#       PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0             1   71       0          0                    0               2
# 1             2   34       0          0                    1               3
# 2             3   80       1          1                    0               1
# 3             4   40       0          2                    0               1
# 4             5   43       0          1                    1               2
# ...         ...  ...     ...        ...                  ...             ...
# 1654       1655   90       0          0                    1               2
# 1655       1656   34       0          0                    2               1
# 1656       1657   84       0          0                    2               3
# 1657       1658   90       0          0                    2               2
# 1658       1659   34       1          1                    0               0
#
# ...

# %%
df['Diagnosis'].unique()
# Out:
# array([1, 0])

# %%
df.isnull().sum()
# Out:
# PatientID                        0
# Age                              0
# Gender                           0
# Ethnicity                        0
# SocioeconomicStatus              0
# EducationLevel                   0
# BMI                              0
# Smoking                          0
# AlcoholConsumption               0
# PhysicalActivity                 0
# DietQuality                      0
# SleepQuality                     0
# FamilyHistoryKidneyDisease       0
# FamilyHistoryHypertension        0
# FamilyHistoryDiabetes            0
# PreviousAcuteKidneyInjury        0
# UrinaryTractInfections           0
# SystolicBP                       0
# DiastolicBP                      0
# FastingBloodSugar                0
# HbA1c                            0
# SerumCreatinine                  0
# BUNLevels                        0
# GFR                              0
# ProteinInUrine                   0
# ACR                              0
# SerumElectrolytesSodium          0
# ...

# %%
df.drop(columns=['PatientID','DoctorInCharge'],axis=1,inplace=True)

# %%
df
# Out:
#       Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel        BMI  \
# 0      71       0          0                    0               2  31.069414
# 1      34       0          0                    1               3  29.692119
# 2      80       1          1                    0               1  37.394822
# 3      40       0          2                    0               1  31.329680
# 4      43       0          1                    1               2  23.726311
# ...   ...     ...        ...                  ...             ...        ...
# 1654   90       0          0                    1               2  39.677059
# 1655   34       0          0                    2               1  28.922015
# 1656   84       0          0                    2               3  21.951219
# 1657   90       0          0                    2               2  24.964149
# 1658   34       1          1                    0               0  19.253258
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
target_col=df['Diagnosis']
nc=df.drop(columns=['Diagnosis'],axis=1)
sc=StandardScaler()
nc=pd.DataFrame(sc.fit_transform(nc),columns=nc.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6c032174245a> in <cell line: 2>()
#       1 from sklearn.preprocessing import StandardScaler
# ----> 2 target_col=df['Diagnosis']
#       3 nc=df.drop(columns=['Diagnosis'],axis=1)
#       4 sc=StandardScaler()
#       5 nc=pd.DataFrame(sc.fit_transform(nc),columns=nc.columns)
#
# NameError: name 'df' is not defined

# %%
fd=pd.concat([nc,target_col],axis=1)

# %%
fd
# Out:
#            Age    Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0     0.806032 -1.031229  -0.712989            -1.259185        0.337031
# 1    -0.995019 -1.031229  -0.712989             0.028724        1.435526
# 2     1.244125  0.969717   0.286883            -1.259185       -0.761465
# 3    -0.702956 -1.031229   1.286755            -1.259185       -0.761465
# 4    -0.556925 -1.031229   0.286883             0.028724        0.337031
# ...        ...       ...        ...                  ...             ...
# 1654  1.730896 -1.031229  -0.712989             0.028724        0.337031
# 1655 -0.995019 -1.031229  -0.712989             1.316633       -0.761465
# 1656  1.438834 -1.031229  -0.712989             1.316633        1.435526
# 1657  1.730896 -1.031229  -0.712989             1.316633        0.337031
# 1658 -0.995019  0.969717   0.286883            -1.259185       -1.859960
#
#            BMI   Smoking  AlcoholConsumption  PhysicalActivity  DietQuality  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
from sklearn.model_selection import train_test_split
x=fd.drop(columns=['Diagnosis'],axis=1)
y=fd['Diagnosis']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9367469879518072

# %%
svc=SVC()
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.927710843373494

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9186746987951807

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8765060240963856

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9307228915662651

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
y_pred=gnb.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.927710843373494

# %%
abc=AdaBoostClassifier()
abc.fit(x_train,y_train)
y_pred=abc.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# 0.9246987951807228

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
y_pred=gbc.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9337349397590361

# %%
bc=BaggingClassifier()
bc.fit(x_train,y_train)
y_pred=bc.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9126506024096386

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report

# Check the dataset shapes
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")

# Get the number of features
num_features = x_train.shape[1]

# Define the model
model = keras.Sequential([
    keras.Input(shape=(num_features,)),  # Correct input layer
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')  # Adjust number of units to match classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# One-hot encode the target variable
y_train_encoded = to_categorical(y_train, num_classes=10)  # Ensure correct num_classes
y_test_encoded = to_categorical(y_test, num_classes=10)

# Check one-hot encoding
print(f"y_train_encoded shape: {y_train_encoded.shape}")
print(f"y_test_encoded shape: {y_test_encoded.shape}")

# Train the model
model.fit(x_train, y_train_encoded, epochs=10, batch_size=32)

# Predict on test data
y_pred_probs = model.predict(x_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test_encoded, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Classification report
print(classification_report(y_test, y_pred))
# Out:
# x_train shape: (1327, 51)
# y_train shape: (1327,)
# x_test shape: (332, 51)
# y_test shape: (332,)
# y_train_encoded shape: (1327, 10)
# y_test_encoded shape: (332, 10)
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5246 - loss: 1.6107
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9190 - loss: 0.3972
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.2819
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9138 - loss: 0.2475
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9198 - loss: 0.2049
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9259 - loss: 0.1951
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9214 - loss: 0.1822
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9457 - loss: 0.1505
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9568 - loss: 0.1349
# Epoch 10/10
# ...

# %%
import seaborn as sns




# Visualization 1: Age Distribution
fig, axs = plt.subplots(2, 1, figsize=(12, 8))
sns.histplot(df['Age'], bins=30, kde=True, ax=axs[0], color='blue').set(title="Age Distribution (Raw Data)")
sns.histplot(fd['Age'], bins=30, kde=True, ax=axs[1], color='green').set(title="Age Distribution (Preprocessed Data)")
axs[0].set_xlabel("Age")
axs[1].set_xlabel("Age")

plt.tight_layout()
plt.show()

# %%
# Visualization 2: BMI Distribution
fig, axs = plt.subplots(2, 1, figsize=(12, 8))
sns.histplot(df['BMI'], bins=30, kde=True, ax=axs[0], color='purple').set(title="BMI Distribution (Raw Data)")
sns.histplot(fd['BMI'], bins=30, kde=True, ax=axs[1], color='orange').set(title="BMI Distribution (Preprocessed Data)")
axs[0].set_xlabel("BMI")
axs[1].set_xlabel("BMI")

plt.tight_layout()
plt.show()

# %%
# Visualization 3: Diagnosis Class Balance
fig, axs = plt.subplots(2, 1, figsize=(12, 8))
sns.countplot(x=df['Diagnosis'], ax=axs[0], palette="Blues").set(title="Diagnosis Class Balance (Raw Data)")
sns.countplot(x=fd['Diagnosis'], ax=axs[1], palette="Greens").set(title="Diagnosis Class Balance (Preprocessed Data)")
axs[0].set_xlabel("Diagnosis Class")
axs[1].set_xlabel("Diagnosis Class")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-27-7b5f5afdb182>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Diagnosis'], ax=axs[0], palette="Blues").set(title="Diagnosis Class Balance (Raw Data)")
# <ipython-input-27-7b5f5afdb182>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=fd['Diagnosis'], ax=axs[1], palette="Greens").set(title="Diagnosis Class Balance (Preprocessed Data)")

# %%
# Visualization 5: GFR Distribution
fig, axs = plt.subplots(2, 1, figsize=(12, 8))
sns.histplot(df['GFR'], bins=30, kde=True, ax=axs[0], color='cyan').set(title="GFR Distribution (Raw Data)")
sns.histplot(fd['GFR'], bins=30, kde=True, ax=axs[1], color='red').set(title="GFR Distribution (Preprocessed Data)")
axs[0].set_xlabel("GFR")
axs[1].set_xlabel("GFR")
# Out:
# Text(0.5, 0, 'GFR')

# %%
# Visualization 1: Age Distribution by Diagnosis Class
plt.figure(figsize=(12, 6))
sns.histplot(data=fd, x='Age', hue='Diagnosis', bins=30, kde=True, palette='viridis')
plt.title('Age Distribution by Diagnosis Class', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend(title='Diagnosis', labels=['Healthy', 'CKD'])
plt.show()

# %%
# Visualization 3: GFR vs Age Scatter Plot
plt.figure(figsize=(12, 6))
sns.scatterplot(data=fd, x='Age', y='GFR', hue='Diagnosis', style='Diagnosis', palette='Set2')
plt.title('GFR vs Age by Diagnosis Class', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('GFR', fontsize=14)
plt.legend(title='Diagnosis', labels=['Healthy', 'CKD'])
plt.show()

# %%
# Visualization 4: Proportion of Diagnosis Classes
plt.figure(figsize=(8, 8))
fd['Diagnosis'].value_counts().plot(kind='pie', autopct='%1.1f%%', labels=['Healthy', 'CKD'], colors=['#66c2a5', '#fc8d62'], startangle=90)
plt.title('Proportion of Diagnosis Classes', fontsize=16)
plt.ylabel('')  # Hide y-axis label for pie chart
plt.show()

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Chronic_Kidney_Dsease_data.csv')
df
# Out:
#       PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0             1   71       0          0                    0               2
# 1             2   34       0          0                    1               3
# 2             3   80       1          1                    0               1
# 3             4   40       0          2                    0               1
# 4             5   43       0          1                    1               2
# ...         ...  ...     ...        ...                  ...             ...
# 1654       1655   90       0          0                    1               2
# 1655       1656   34       0          0                    2               1
# 1656       1657   84       0          0                    2               3
# 1657       1658   90       0          0                    2               2
# 1658       1659   34       1          1                    0               0
#
# ...

# %%
df['Diagnosis'].unique()
# Out:
# array([1, 0])

# %%
df.isnull().sum()
# Out:
# PatientID                        0
# Age                              0
# Gender                           0
# Ethnicity                        0
# SocioeconomicStatus              0
# EducationLevel                   0
# BMI                              0
# Smoking                          0
# AlcoholConsumption               0
# PhysicalActivity                 0
# DietQuality                      0
# SleepQuality                     0
# FamilyHistoryKidneyDisease       0
# FamilyHistoryHypertension        0
# FamilyHistoryDiabetes            0
# PreviousAcuteKidneyInjury        0
# UrinaryTractInfections           0
# SystolicBP                       0
# DiastolicBP                      0
# FastingBloodSugar                0
# HbA1c                            0
# SerumCreatinine                  0
# BUNLevels                        0
# GFR                              0
# ProteinInUrine                   0
# ACR                              0
# SerumElectrolytesSodium          0
# ...

# %%
df.drop(columns=['PatientID','DoctorInCharge'],axis=1,inplace=True)

# %%
df
# Out:
#       Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel        BMI  \
# 0      71       0          0                    0               2  31.069414
# 1      34       0          0                    1               3  29.692119
# 2      80       1          1                    0               1  37.394822
# 3      40       0          2                    0               1  31.329680
# 4      43       0          1                    1               2  23.726311
# ...   ...     ...        ...                  ...             ...        ...
# 1654   90       0          0                    1               2  39.677059
# 1655   34       0          0                    2               1  28.922015
# 1656   84       0          0                    2               3  21.951219
# 1657   90       0          0                    2               2  24.964149
# 1658   34       1          1                    0               0  19.253258
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
target_col=df['Diagnosis']
nc=df.drop(columns=['Diagnosis'],axis=1)
sc=StandardScaler()
nc=pd.DataFrame(sc.fit_transform(nc),columns=nc.columns)

# %%
fd=pd.concat([nc,target_col],axis=1)

# %%
fd
# Out:
#            Age    Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0     0.806032 -1.031229  -0.712989            -1.259185        0.337031
# 1    -0.995019 -1.031229  -0.712989             0.028724        1.435526
# 2     1.244125  0.969717   0.286883            -1.259185       -0.761465
# 3    -0.702956 -1.031229   1.286755            -1.259185       -0.761465
# 4    -0.556925 -1.031229   0.286883             0.028724        0.337031
# ...        ...       ...        ...                  ...             ...
# 1654  1.730896 -1.031229  -0.712989             0.028724        0.337031
# 1655 -0.995019 -1.031229  -0.712989             1.316633       -0.761465
# 1656  1.438834 -1.031229  -0.712989             1.316633        1.435526
# 1657  1.730896 -1.031229  -0.712989             1.316633        0.337031
# 1658 -0.995019  0.969717   0.286883            -1.259185       -1.859960
#
#            BMI   Smoking  AlcoholConsumption  PhysicalActivity  DietQuality  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
from sklearn.model_selection import train_test_split
x=fd.drop(columns=['Diagnosis'],axis=1)
y=fd['Diagnosis']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-94d3d89f0c07> in <cell line: 1>()
# ----> 1 lr=LogisticRegression()
#       2 lr.fit(x_train,y_train)
#       3 y_pred=lr.predict(x_test)
#       4 print(accuracy_score(y_test,y_pred))
#
# NameError: name 'LogisticRegression' is not defined

# %%
svc=SVC()
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.927710843373494

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9186746987951807

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8765060240963856

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9307228915662651

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
y_pred=gnb.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.927710843373494

# %%
abc=AdaBoostClassifier()
abc.fit(x_train,y_train)
y_pred=abc.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# 0.9246987951807228

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
y_pred=gbc.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9337349397590361

# %%
bc=BaggingClassifier()
bc.fit(x_train,y_train)
y_pred=bc.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9126506024096386

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report

# Check the dataset shapes
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")

# Get the number of features
num_features = x_train.shape[1]

# Define the model
model = keras.Sequential([
    keras.Input(shape=(num_features,)),  # Correct input layer
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')  # Adjust number of units to match classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# One-hot encode the target variable
y_train_encoded = to_categorical(y_train, num_classes=10)  # Ensure correct num_classes
y_test_encoded = to_categorical(y_test, num_classes=10)

# Check one-hot encoding
print(f"y_train_encoded shape: {y_train_encoded.shape}")
print(f"y_test_encoded shape: {y_test_encoded.shape}")

# Train the model
model.fit(x_train, y_train_encoded, epochs=10, batch_size=32)

# Predict on test data
y_pred_probs = model.predict(x_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test_encoded, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Classification report
print(classification_report(y_test, y_pred))
# Out:
# x_train shape: (1327, 51)
# y_train shape: (1327,)
# x_test shape: (332, 51)
# y_test shape: (332,)
# y_train_encoded shape: (1327, 10)
# y_test_encoded shape: (332, 10)
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5246 - loss: 1.6107
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9190 - loss: 0.3972
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.2819
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9138 - loss: 0.2475
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9198 - loss: 0.2049
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9259 - loss: 0.1951
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9214 - loss: 0.1822
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9457 - loss: 0.1505
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9568 - loss: 0.1349
# Epoch 10/10
# ...

# %%
import seaborn as sns




# Visualization 1: Age Distribution
fig, axs = plt.subplots(2, 1, figsize=(12, 8))
sns.histplot(df['Age'], bins=30, kde=True, ax=axs[0], color='blue').set(title="Age Distribution (Raw Data)")
sns.histplot(fd['Age'], bins=30, kde=True, ax=axs[1], color='green').set(title="Age Distribution (Preprocessed Data)")
axs[0].set_xlabel("Age")
axs[1].set_xlabel("Age")

plt.tight_layout()
plt.show()

# %%
# Visualization 2: BMI Distribution
fig, axs = plt.subplots(2, 1, figsize=(12, 8))
sns.histplot(df['BMI'], bins=30, kde=True, ax=axs[0], color='purple').set(title="BMI Distribution (Raw Data)")
sns.histplot(fd['BMI'], bins=30, kde=True, ax=axs[1], color='orange').set(title="BMI Distribution (Preprocessed Data)")
axs[0].set_xlabel("BMI")
axs[1].set_xlabel("BMI")

plt.tight_layout()
plt.show()

# %%
# Visualization 3: Diagnosis Class Balance
fig, axs = plt.subplots(2, 1, figsize=(12, 8))
sns.countplot(x=df['Diagnosis'], ax=axs[0], palette="Blues").set(title="Diagnosis Class Balance (Raw Data)")
sns.countplot(x=fd['Diagnosis'], ax=axs[1], palette="Greens").set(title="Diagnosis Class Balance (Preprocessed Data)")
axs[0].set_xlabel("Diagnosis Class")
axs[1].set_xlabel("Diagnosis Class")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-27-7b5f5afdb182>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Diagnosis'], ax=axs[0], palette="Blues").set(title="Diagnosis Class Balance (Raw Data)")
# <ipython-input-27-7b5f5afdb182>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=fd['Diagnosis'], ax=axs[1], palette="Greens").set(title="Diagnosis Class Balance (Preprocessed Data)")

# %%
# Visualization 5: GFR Distribution
fig, axs = plt.subplots(2, 1, figsize=(12, 8))
sns.histplot(df['GFR'], bins=30, kde=True, ax=axs[0], color='cyan').set(title="GFR Distribution (Raw Data)")
sns.histplot(fd['GFR'], bins=30, kde=True, ax=axs[1], color='red').set(title="GFR Distribution (Preprocessed Data)")
axs[0].set_xlabel("GFR")
axs[1].set_xlabel("GFR")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b4bfe02b3748> in <cell line: 2>()
#       1 # Visualization 5: GFR Distribution
# ----> 2 fig, axs = plt.subplots(2, 1, figsize=(12, 8))
#       3 sns.histplot(df['GFR'], bins=30, kde=True, ax=axs[0], color='cyan').set(title="GFR Distribution (Raw Data)")
#       4 sns.histplot(fd['GFR'], bins=30, kde=True, ax=axs[1], color='red').set(title="GFR Distribution (Preprocessed Data)")
#       5 axs[0].set_xlabel("GFR")
#
# NameError: name 'plt' is not defined

# %%
# Visualization 1: Age Distribution by Diagnosis Class
plt.figure(figsize=(12, 6))
sns.histplot(data=fd, x='Age', hue='Diagnosis', bins=30, kde=True, palette='viridis')
plt.title('Age Distribution by Diagnosis Class', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend(title='Diagnosis', labels=['Healthy', 'CKD'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-58d189ab93b1> in <cell line: 2>()
#       1 # Visualization 1: Age Distribution by Diagnosis Class
# ----> 2 plt.figure(figsize=(12, 6))
#       3 sns.histplot(data=fd, x='Age', hue='Diagnosis', bins=30, kde=True, palette='viridis')
#       4 plt.title('Age Distribution by Diagnosis Class', fontsize=16)
#       5 plt.xlabel('Age', fontsize=14)
#
# NameError: name 'plt' is not defined

# %%
# Visualization 3: GFR vs Age Scatter Plot
plt.figure(figsize=(12, 6))
sns.scatterplot(data=fd, x='Age', y='GFR', hue='Diagnosis', style='Diagnosis', palette='Set2')
plt.title('GFR vs Age by Diagnosis Class', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('GFR', fontsize=14)
plt.legend(title='Diagnosis', labels=['Healthy', 'CKD'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-88d20ee47918> in <cell line: 2>()
#       1 # Visualization 3: GFR vs Age Scatter Plot
# ----> 2 plt.figure(figsize=(12, 6))
#       3 sns.scatterplot(data=fd, x='Age', y='GFR', hue='Diagnosis', style='Diagnosis', palette='Set2')
#       4 plt.title('GFR vs Age by Diagnosis Class', fontsize=16)
#       5 plt.xlabel('Age', fontsize=14)
#
# NameError: name 'plt' is not defined

# %%
# Visualization 4: Proportion of Diagnosis Classes
plt.figure(figsize=(8, 8))
fd['Diagnosis'].value_counts().plot(kind='pie', autopct='%1.1f%%', labels=['Healthy', 'CKD'], colors=['#66c2a5', '#fc8d62'], startangle=90)
plt.title('Proportion of Diagnosis Classes', fontsize=16)
plt.ylabel('')  # Hide y-axis label for pie chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3fefea83d1e6> in <cell line: 2>()
#       1 # Visualization 4: Proportion of Diagnosis Classes
# ----> 2 plt.figure(figsize=(8, 8))
#       3 fd['Diagnosis'].value_counts().plot(kind='pie', autopct='%1.1f%%', labels=['Healthy', 'CKD'], colors=['#66c2a5', '#fc8d62'], startangle=90)
#       4 plt.title('Proportion of Diagnosis Classes', fontsize=16)
#       5 plt.ylabel('')  # Hide y-axis label for pie chart
#
# NameError: name 'plt' is not defined
