# %%
import pandas as pd

# %%
import requests

# %%
import json

# %%
response = requests.get('')

# %%
df = pd.DataFrame(response.json()['results'])

# %%
df.head()

# %%
df=pd.DataFrame()

# %%
for page in range(1,429):
    response = requests.get('')
    temp_df = pd.DataFrame(response.json()['results'])
    df = pd.concat([df,temp_df],ignore_index=True)

# %%
df.shape

# %%
df.to_csv('movies.csv')

# %% [markdown]
# #API

# %%
import http.client

conn = http.client.HTTPSConnection("linkedin-data-api.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "879ecf7ac2msh4be1ffcbcbfc4c3p1cf975jsn2e14c19b8539",
    'x-rapidapi-host': "linkedin-data-api.p.rapidapi.com"
}

conn.request("GET", "/get-profile-comments?username=williamhgates", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"success":true,"message":"","data":[{"highlightedComments":["Thanks for having me. It’s inspiring to see how far research for Alzheimer's has come."],"highlightedCommentsActivityCounts":[{"text":"Thanks for having me. It’s inspiring to see how far research for Alzheimer's has come.","totalReactionCount":38,"likeCount":33,"empathyCount":5}],"text":"This afternoon, we welcomed Bill Gates as he toured labs at the Indiana University School of Medicine and met with key faculty members to learn more about the expansive Alzheimer’s disease research happening right here in Indianapolis.","commentUrl":"https://www.linkedin.com/feed/update/urn:li:ugcPost:7231813250051383296?commentUrn=urn%3Ali%3Acomment%3A%28ugcPost%3A7231813250051383296%2C7234959305127444481%29\u0026dashCommentUrn=urn%3Ali%3Afsd_comment%3A%287234959305127444481%2Curn%3Ali%3AugcPost%3A7231813250051383296%29","totalReactionCount":3254,"likeCount":2853,"appreciationCount":13,"empathyCount":192,"InterestCount":9,"praiseCount":18
# ...

# %%
# Decode and parse the response
response_json = json.loads(data.decode("utf-8"))

# Convert the JSON response to a DataFrame
if isinstance(response_json, list):
    df = pd.DataFrame(response_json)
elif isinstance(response_json, dict):
    df = pd.DataFrame([response_json])

# Print or inspect the DataFrame
print(df)
# Out:
#    success message                                               data
# 0     True          [{'highlightedComments': ['Thanks for having m...

# %%
response_json
# Out:
# {'success': True,
#  'message': '',
#  'data': [{'highlightedComments': ["Thanks for having me. It’s inspiring to see how far research for Alzheimer's has come."],
#    'highlightedCommentsActivityCounts': [{'text': "Thanks for having me. It’s inspiring to see how far research for Alzheimer's has come.",
#      'totalReactionCount': 38,
#      'likeCount': 33,
#      'empathyCount': 5}],
#    'text': 'This afternoon, we welcomed Bill Gates as he toured labs at the Indiana University School of Medicine and met with key faculty members to learn more about the expansive Alzheimer’s disease research happening right here in Indianapolis.',
#    'commentUrl': 'https://www.linkedin.com/feed/update/urn:li:ugcPost:7231813250051383296?commentUrn=urn%3Ali%3Acomment%3A%28ugcPost%3A7231813250051383296%2C7234959305127444481%29&dashCommentUrn=urn%3Ali%3Afsd_comment%3A%287234959305127444481%2Curn%3Ali%3AugcPost%3A7231813250051383296%29',
#    'totalReactionCount': 3254,
#    'likeCount': 2853,
# ...

# %%
df.to_csv("output.csv", index=False)
df.to_excel("output.xlsx", index=False)

# %%
from google.colab import files
files.download('output.xlsx')
