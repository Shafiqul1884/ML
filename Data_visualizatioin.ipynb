# %% [markdown]
# # Statistics for Data scientists And Data visualisation

# %% [markdown]
# **Learning outcome**
# 1. Mean
# 2. Median
# 3. Mode
# 4. Percentile
# 5. Deviations
# 6. Variance
# 7. Standard deviations
# 8. BoxPlot
# 9. Histogram
# 10. Bar charts
# 11. Pie charts
# 12. Scatterplot
# 13. Correlation
# 14. Correlation Coefficient
# 15. correlation Matrix

# %%
file_path = 'iris.csv'

# %%
#Dataset read
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.4           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.3          0.2     setosa
# 4             5.1          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import statistics as stat

# %% [markdown]
# **Mean**

# %%
stat.mean(df['sepal_length'])
# Out:
# 5.844

# %% [markdown]
# **Median**

# %%
stat.median(df['sepal_length'])
# Out:
# 5.8

# %% [markdown]
# **Mode**

# %%
stat.mode(df['sepal_length'])
# Out:
# 5.1

# %% [markdown]
# **Percentile**

# %%
np.percentile(df['sepal_length'], 50)
# Out:
# 5.8

# %%
df['sepal_length'].quantile([0.05,0.25,0.5,0.75])
# Out:
# 0.05    4.6
# 0.25    5.1
# 0.50    5.8
# 0.75    6.4
# Name: sepal_length, dtype: float64

# %% [markdown]
# **Variance**

# %%
stat.variance(df['sepal_length'])
# Out:
# 0.6846281879194631

# %% [markdown]
# **Standard Deviations**

# %%
x = np.std(df['sepal_length'])

print(x)
# Out:
# 0.8246599299105056

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.844000     3.056667      3.757333     1.198667
# std        0.827423     0.434489      1.766213     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Data visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# Line Plot

# %%
X=[10,5,20,15,35]


plt.plot(X,color='r',linestyle=':',linewidth=2,marker='o')
plt.show()

# %% [markdown]
# Subplot

# %%
X=[10,5,20,15,35]

plt.subplot(2,2,1)
plt.plot(X,color='r',linestyle='-',linewidth=2,marker='o',label='Line')
plt.legend()

plt.subplot(2,2,2)
plt.plot(X,color='g',linestyle=':',linewidth=2,marker='*',label='Dot')
plt.legend()

plt.subplot(2,2,3)
plt.plot(X,color='b',linestyle='--',linewidth=2,marker='s',label='Dash')
plt.legend()

plt.subplot(2,2,4)
plt.plot(X,color='k',linestyle='-.',linewidth=2,marker='D',label='Dash_Doted')
plt.legend()


plt.show()

# %% [markdown]
# **Scatter Plot**

# %%
x = df['sepal_length']
y = df['sepal_width']

plt.scatter(x, y, c='r')
plt.show()

# %%
x = df['sepal_length']
y = df['sepal_width']

x1 = df['petal_length']
y1 = df['petal_width']

plt.scatter(x, y, c='r')
plt.scatter(x1, y1, c='g')

#plt.grid()

plt.show()

# %%
x = df['sepal_length']
y = df['sepal_width']

x1 = df['petal_length']
y1 = df['petal_width']

plt.scatter(x, y, c='r', label='sepal length & Width')
plt.scatter(x1, y1, c='g',label='Petal length & Width')

plt.legend()

#plt.grid()

plt.show()

# %%
x = df['sepal_length']
y = df['sepal_width']

x1 = df['petal_length']
y1 = df['petal_width']

plt.title('Sepal vs Petal')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.scatter(x, y, c='r', label='sepal length & Width')
plt.scatter(x1, y1, c='g',label='Petal length & Width')

plt.legend()

#plt.grid()

plt.show()

# %% [markdown]
# **Bar charts**

# %%
x = [0.25,1.25,2.25,3.25,4.25]
y = [50,40,70,80,20]

x1 = [.75,1.75,2.75,3.75,4.75]
y1 = [80,20,20,50,60]

plt.title('Information')
plt.xlabel('Days')
plt.ylabel('Distance (km)')

plt.bar(x,y,label='BMW',color='g',width=.5)
plt.bar(x1,y1,label='Audi',color='r',width=.5)

plt.legend()

# %%
data = df['species'].value_counts()

name = data.index
count = data.values

plt.title('Scores')
plt.xlabel('Names')
plt.ylabel('Total Count')

plt.bar(name,count)
# Out:
# <BarContainer object of 3 artists>

# %%
data = df['species'].value_counts()

name = data.index
count = data.values

plt.title('Scores')
plt.xlabel('Names')
plt.ylabel('Total Count')

plt.barh(name,count)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# **Pie charts**

# %%
slices = [4,2,1,3]

activity = ["Sleeping","Eating", "Working", "Playing"]

cols = ['g','b','r','m']

plt.pie(slices,
        labels=activity,
        colors=cols,
        startangle=45,
        shadow=True,
        explode=(0,0,0,0),
        autopct="%1.1f%%")

plt.title('Scatter Plot')
plt.show()

# %%
slices =df['species'].value_counts()
activities = ['Setosa','Versicolor','Virginica']
cols = ['g','b','r']

plt.pie(slices,
  labels=activities,
  colors=cols,
  startangle=90,
  shadow= False,
  explode=(0,0.1,0),
  autopct='%1.0f%%',
  radius=1.2)

plt.title('Pie Plot')
plt.show()

# %% [markdown]
# **Histogram**

# %%
x = [1,1,2,3,3,5,7,8,9,10,
     10,11,11,13,13,15
     ]

plt.hist(x, bins=10,edgecolor='k',linewidth=1)
plt.show()

# %% [markdown]
# **Box Plot**

# %%
value1=[62,5,91,25,36,32,96,95,3,90,95,32,27,55,100,15,71,11,37,21]
value2=[23,89,12,78,72,89,25,69,68,86,19,49,15,16,16,75,65,31,25,52]
value3=[59,73,70,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

box_plot_data = [value1,value2,value3]
plt.boxplot(box_plot_data,patch_artist=True,labels=['subject1','subject2','subject3'])
plt.show()

# %% [markdown]
# # Seaborn

# %%
df=sb.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# line_plot_with_seaborn

# %%
sb.lineplot(x='sepal_length', y='sepal_width', data=df, hue='species', marker='o', linestyle=':')
plt.show()

# %% [markdown]
# Histogram_with_seaborn

# %%
sb.histplot(df['petal_length'],bins=10,kde=True,color='c')
plt.show()

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1=df.iloc[40:60]

# %% [markdown]
# Barplot_with_seaborn

# %%
sb.barplot(x=df1['petal_length'],y=df1['petal_width'],hue=df['species'])
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sb.barplot(x=df1['petal_length'],y=df1['petal_width'],hue=df['species'],orient='h')
plt.show()

# %% [markdown]
# Scatter_plot_with_seaborn

# %%
sb.scatterplot(x=df['petal_length'],y=df['petal_width'])
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sb.scatterplot(x=df['petal_length'],y=df['petal_width'],hue=df['species'])
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sb.scatterplot(x=df['petal_length'],y=df['petal_width'],hue=df['species'],style=df['species'],palette='flare')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# **Correlation**

# %%
df.corr()
# Out:
# <ipython-input-48-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.figure(1 , figsize = (10 , 5))
sb.heatmap(df.corr(), annot = True)
plt.title('Heatmap for the Data')
plt.show()
# Out:
# <ipython-input-49-34d50527f185>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(df.corr(), annot = True)
